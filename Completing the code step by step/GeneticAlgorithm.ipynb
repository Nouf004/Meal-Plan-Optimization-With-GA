# %%
# Imports
from dataclasses import dataclass
import random
import numpy as np
from deap import base, creator, tools, algorithms
import csv
from deap.tools import cxOnePoint, cxTwoPoints
import time

SEED = 42
def reset_seed():
    random.seed(SEED)
    np.random.seed(SEED)

# %%
# A gene contains 2 attributes : the food item's name and the number of servings of this item
@dataclass
class Gene:
    food_item_name: str
    serving: int

# %%
# We make a list representing all the meals we have in 1 chromosome 
Meals =["Breakfast", "Snack 1", "Lunch", "Snack 2", "Dinner"]
# We make a list representing all the food groups we have in 1 meal
Food_Groups =["Vegetables", "Fruits", "Grains", "Protein", "Dairy", "Fats and Oils"]

# %%
# Load dataset
def load_food_data(csv_path):
    food_data = {}
    meal_flags = {}

    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)

        for row in reader:
            group = row['Category']
            food = row['Food Item']

            if group not in food_data:
                food_data[group] = {}

            # Safely convert numeric columns, use 0 if empty
            def safe_float(x):
                try:
                    return float(x)
                except (ValueError, TypeError):
                    return 0.0

            food_data[group][food] = {
                'p': safe_float(row['Protein (g)']),
                'f': safe_float(row['Fats (g)']),
                'c': safe_float(row['Carbohydrates (g)']),
                'cal': safe_float(row['Calories (kcal)']),
                'pref': safe_float(row['User Preference'])
            }

            # Safely convert meal flags (0 if empty)
            def safe_int(x):
                try:
                    return int(x)
                except (ValueError, TypeError):
                    return 0

            meal_flags[food] = {
                'Breakfast': safe_int(row['Breakfast']),
                'Snack 1': safe_int(row['Snack 1']),
                'Lunch': safe_int(row['Lunch']),
                'Snack 2': safe_int(row['Snack 2']),
                'Dinner': safe_int(row['Dinner'])
            }

    return food_data, meal_flags

FOOD_DATA, MEAL_FLAGS = load_food_data("Processed_Bahrain_Food_Dataset.csv")

# %%
# Dictionary that contains all the saudi guideline's servings
SERVING_GUIDELINES_BY_KCAL = {
    1200: {
        "Breakfast": {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 2, "Fruits": 0, "Fats and Oils": 0},
        "Snack 2":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 0}
    },

    1300: {
        "Breakfast": {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 0}
    },

    1400: {
        "Breakfast": {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 1, "Vegetables": 2, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 0}
    },

    1500: {
        "Breakfast": {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 2, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 0}
    },

    1600: {
        "Breakfast": {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 2, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 0}
    },

    1700: {
        "Breakfast": {"Grains": 3, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 2, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 0}
    },

    1800: {
        "Breakfast": {"Grains": 3, "Dairy": 1, "Protein": 2, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 1}
    },

    1900: {
        "Breakfast": {"Grains": 3, "Dairy": 1, "Protein": 2, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 2, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 1}
    },

    2000: {
        "Breakfast": {"Grains": 3, "Dairy": 1, "Protein": 2, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 2, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 2, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 0}
    },

    2200: {
        "Breakfast": {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 2, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 2, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 2, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 1}
    }
}

# %%
# DEAP Configuration
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()

# Initialize Population
def create_individual():
    # Initializes 30 genes following 1600 kcal
    genes = []
    for meal in Meals:
        for group in Food_Groups:
            # Get the fixed serving count for this meal/group
            serving_count = SERVING_GUIDELINES_BY_KCAL[TARGET_KCAL][meal][group]

           # Filter foods allowed for this meal
            allowed_foods = [
                food for food in FOOD_DATA[group].keys() if MEAL_FLAGS[food][meal] == 1
            ]
            if not allowed_foods:
                allowed_foods = list(FOOD_DATA[group].keys())  # fallback

            # Randomly select food from allowed foods
            food_name = random.choice(allowed_foods)

            # Create gene with guideline serving count
            genes.append(Gene(food_item_name=food_name, serving=serving_count))


    return creator.Individual(genes)

toolbox.register("individual", create_individual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# Fitness Function
def evaluate_meal_plan(individual):
    total_p = 0.0 # Protein grams
    total_f = 0.0 # Fat grams
    total_c = 0.0 # Carbohydrates grams
    total_cal = 0.0 # Total Calories
    total_pref = 0.0 # Total user preference

    # Sum up all grams and calories based on food item and serving count
    for gene in individual:
        group_name = None
        # Find which group this food belongs to
        for group, foods in FOOD_DATA.items():
            if gene.food_item_name in foods:
                group_name = group
                break

        if group_name:
            stats = FOOD_DATA[group_name][gene.food_item_name]
            total_p += stats['p'] * gene.serving
            total_f += stats['f'] * gene.serving
            total_c += stats['c'] * gene.serving
            total_cal += stats['cal'] * gene.serving
            if gene.serving > 0:
              total_pref += stats['pref']
    # Calculate actual macro percentages (p_c, p_p, p_f)
    g_total = total_p + total_f + total_c
    if g_total == 0: return 0, # Avoid division by zero

    p_p = total_p / g_total
    p_f = total_f / g_total
    p_c = total_c / g_total

    # Target Ratios (The AMDR values)
    r_p, r_f, r_c = 0.20, 0.25, 0.55

    # Objective function: J_macro (Squared Error)
    j_macro = (p_c - r_c)**2 + (p_p - r_p)**2 + (p_f - r_f)**2

    # Total calorie constraint (J_cal)
    r = (total_cal - TARGET_KCAL) / TARGET_KCAL
    j_cal = min(1, r**2)

    # Variety constraint (J_var)
    N = sum(1 for gene in individual if gene.serving > 0) # total number of food items in the chromosome (N is taken from the report)
    # count food appearance
    food_appearance={}
    for gene in individual:
        if gene.serving>0:
            food_appearance[gene.food_item_name]= food_appearance.get(gene.food_item_name, 0) + 1
    # Calculate the penalty for variety
    j_var = 0
    for food_name,count in food_appearance.items():
        # we penalize if the food item appears more than once
        if count > 1:
            j_var += max(0,count-1)**2
    # Normalize the penalty
    j_var = j_var / ((N-1)**2)

    # User preference constraint (J_pref)
    j_pref = total_pref / N


    # Calculate the score
    w_macro, w_cal, w_var, w_pref = 0.35, 0.35, 0.15, 0.15 
    score = w_macro * j_macro + w_var * j_var + w_cal * j_cal + w_pref *  j_pref

    # store the penalties to print later
    individual.j_var= j_var
    individual.j_macro = j_macro
    individual.j_cal = j_cal
    individual.j_pref = j_pref

    # We want to minimize score, so we return a fitness that increases as score decreases
    return 1 / (1 + score),

# Crossover
def one_cx_meal_plan(parent1, parent2):
    GROUPS = 6
    MEALS = 5

    m1 = random.randrange(1, MEALS)
    cut = m1 * GROUPS
    parent1[cut:], parent2[cut:] = parent2[cut:], parent1[cut:]
    return parent1, parent2

def two_cx_meal_plan(parent1, parent2):
    GROUPS = 6
    MEALS = 5

    # Choose 2 meal cut points
    m1, m2 = sorted(random.sample(range(1, MEALS), 2))
    cut1, cut2 = m1 * GROUPS, m2 * GROUPS

    # Swap full meals
    parent1[cut1:cut2], parent2[cut1:cut2] = parent2[cut1:cut2], parent1[cut1:cut2]

    return parent1, parent2

# Mutation
def mutate_meal_plan(individual):
    mutations_done = 0
    all_indices = list(range(len(individual))) # List of all possible indices in the chromosome
    random.shuffle(all_indices) # Shuffle to pick randomly without repeating the same one

    for i in all_indices:
        if mutations_done >= 2:
            break  # Stop once we have mutated 2 genes

        # Check if the serving size is not zero
        if individual[i].serving > 0:
            # Find which group it belongs to (Vegetables, Grains, ...)
            group_name = Food_Groups[i % 6]
            # What meal it belongs to (Breakfast, Snack 1,...)
            meal = Meals[i // 6]

            # Check compatibility
            allowed_foods = [
                food for food in FOOD_DATA[group_name].keys() if MEAL_FLAGS[food][meal] == 1
            ]
            if allowed_foods:
                # Pick a new food name from food group dictionary, but the serving remains the same
                individual[i].food_item_name = random.choice(allowed_foods)
                mutations_done += 1
    return individual,

toolbox.register("evaluate", evaluate_meal_plan)
toolbox.register("select", tools.selTournament, tournsize=3) # Tournament selection (From report: For the selection strategy, we plan to compare tournament selection and roulette-wheel selection)
toolbox.register("mate", cxOnePoint) # one-point crossover
toolbox.register("mutate", mutate_meal_plan)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "

# %%
# Execution Loop
def run_simulation(target_kcal, pop_size, cxpb, mutpb):
    global TARGET_KCAL
    TARGET_KCAL = target_kcal   # tells create_individual which guideline to use

    pop = toolbox.population(n=pop_size) # try 30, 50, 100 (from parameters)

    hof = tools.HallOfFame(1) # Keeps the absolute best found across all generations

    mu = len(pop) # Number of individuals to select for the next generation
    lambd = 100 # Number of children to produce in each generation
    MAX_GEN = 300 #max num no more
    PATIENCE = 10 #after 10 gen if there is no progress stop, try 10, 20, 30 (change at the end after main parameters)
    EPS = 1e-6  #small new update ignor
    best_so_far = None
    stagnant = 0
    # Statistics object
    stats = tools.Statistics(lambda ind: ind.fitness.values[0])
    stats.register("avg", np.mean)
    stats.register("min", np.min)
    stats.register("max", np.max)
    for gen in range(MAX_GEN):

        # run ONE generation
        algorithms.eaMuPlusLambda(
            pop, toolbox,
            mu=mu,
            lambda_=lambd,
            cxpb=cxpb, #try 0.5, 0.7, 0.9 (from parameters)
            mutpb=mutpb, #try 0.05, 0.1, 0.2 (from parameters)
            ngen=1,
            stats=stats,
            halloffame=hof,
            verbose=False
        )
        hof.update(pop)


        current_best = hof[0].fitness.values[0]

        if best_so_far is None or current_best > best_so_far + EPS:
            best_so_far = current_best
            stagnant = 0
        else:
            stagnant += 1

        if stagnant >= PATIENCE:
            print(f"\nEarly stopping at generation {gen+1} (no improvement for {PATIENCE} gens)")
            break
    print(f"Final Gen {gen+1} | best={current_best:.8f} | stagnant={stagnant}/{PATIENCE}")
    print("-" * 50)


    return hof[0]

# %%
# Random Search
def run_random_search(num_trials):
    best_individual = None
    best_fitness = -float("inf")


    for i in range(num_trials):
        ind = create_individual()  # same initialization as GA
        fitness = evaluate_meal_plan(ind)[0]

        if fitness > best_fitness:
            best_fitness = fitness
            best_individual = ind

    return best_individual, best_fitness

# %%
def print_meal_plan(individual):
    total_p = total_f = total_c = total_cal = 0.0

    #print(f"\n{'MEAL':<12} | {'GROUP':<14} | {'FOOD ITEM':<25} | {'SERV.':<6} | {'P (g)':<6} | {'F (g)':<6} | {'C (g)':<6} | {'CALS':<6} | {'PREF':<6}")
    #print("-" * 100)

    for i, gene in enumerate(individual):
        meal = Meals[i // 6]
        group = Food_Groups[i % 6]
        stats = FOOD_DATA[group][gene.food_item_name]
        p = stats['p'] * gene.serving
        f = stats['f'] * gene.serving
        c = stats['c'] * gene.serving
        cal = stats['cal'] * gene.serving
        pref = stats['pref'] if gene.serving > 0 else 0
        total_p += p
        total_f += f
        total_c += c
        total_cal += cal
        #print(f"{meal:<12} | {group:<14} | {gene.food_item_name:<25} | {gene.serving:<6} | {p:<6.1f} |{f:<6.1f} | {c:<6.1f} | {cal:<6.1f} | {pref:<6.2f}")

    g_total = total_p + total_f + total_c
    p_p = (total_p / g_total) * 100
    p_f = (total_f / g_total) * 100
    p_c = (total_c / g_total) * 100
    variety = (1 - individual.j_var) * 100
    calories = (total_cal / TARGET_KCAL) * 100
    preference_score = (1 - individual.j_pref) * 100

    print("\n" + "="*40)
    print("       DAILY NUTRITION SUMMARY")
    print("="*40)
    print(f"Total Energy:   {total_cal:.1f} kcal")
    print(f"Total Weight:   {g_total:.1f} g (Macro Grams)")
    print("-" * 40)
    print(f"Nutrient        | Actual % | Target %")
    print(f"Carbs (c)       | {p_c:>7.1f}% | 55.0%")
    print(f"Protein (p)     | {p_p:>7.1f}% | 20.0%")
    print(f"Fats (f)        | {p_f:>7.1f}% | 25.0%")
    print(f"Meal variety    | {variety:>7.1f}% | 100%")
    print(f"Meal calorie    | {calories:>7.1f}% | 100%")
    print(f"User preference | {preference_score:>7.1f}% | 100%")
    print("="*40)

# %%
# Execute the Simulation
# Grid search parameters
pop_sizes = [30, 50, 100]
cx_probs = [0.5, 0.7, 0.9]
mut_probs = [0.05, 0.1, 0.2]

TARGET_KCAL = 1600

results = [] # Results of all parameter combinations

 # Nested loop trying all possible combinations
for pop_size in pop_sizes:
    for cxpb in cx_probs:
        for mutpb in mut_probs:
            if cxpb + mutpb > 1.0:
                continue  # The sum of cxpb and mutpb must be less than or equal to 1, otherwise error

            reset_seed()

            print(f"\npop={pop_size}, cxpb={cxpb}, mutpb={mutpb}")
            start_time = time.time()
            best_plan = run_simulation(TARGET_KCAL, pop_size=pop_size, cxpb=cxpb, mutpb=mutpb)
            end_time = time.time()
            runtime_sec = end_time - start_time
            #print_meal_plan(best_plan)
            results.append({ # Add to results
                "pop": pop_size,
                "cxpb": cxpb,
                "mutpb": mutpb,
                "fitness": best_plan.fitness.values[0],
                "runtime_sec": runtime_sec
            })
# Sort results by fitness (best to worst)
results_sorted = sorted(results, key=lambda x: x["fitness"], reverse=True)

# Print summary table
print("\n=== Final Summary: Best to Worst Fitness ===")
print(f"{'Pop':>5} | {'CxPb':>5} | {'MutPb':>5} | {'Fitness':>10} | {'Runtime (s)':>10}")
print("-" * 50)
for r in results_sorted:
    print(f"{r['pop']:>5} | {r['cxpb']:>5.2f} | {r['mutpb']:>5.2f} | {r['fitness']:>10.6f} | {r['runtime_sec']:>10.2f}")
# Out:
# pop=30, cxpb=0.5, mutpb=0.05
#
# Early stopping at generation 30 (no improvement for 10 gens)
# Final Gen 30 | best=0.96276624 | stagnant=10/10
# --------------------------------------------------
#
# pop=30, cxpb=0.5, mutpb=0.1
#
# Early stopping at generation 40 (no improvement for 10 gens)
# Final Gen 40 | best=0.97593266 | stagnant=10/10
# --------------------------------------------------
#
# pop=30, cxpb=0.5, mutpb=0.2
#
# Early stopping at generation 58 (no improvement for 10 gens)
# Final Gen 58 | best=0.98432407 | stagnant=10/10
# --------------------------------------------------
#
# pop=30, cxpb=0.7, mutpb=0.05
#
# Early stopping at generation 43 (no improvement for 10 gens)
# Final Gen 43 | best=0.97031059 | stagnant=10/10
# --------------------------------------------------
#
# pop=30, cxpb=0.7, mutpb=0.1
#
# Early stopping at generation 55 (no improvement for 10 gens)
# Final Gen 55 | best=0.98223311 | stagnant=10/10
# --------------------------------------------------
#
# pop=30, cxpb=0.7, mutpb=0.2
#
# Early stopping at generation 47 (no improvement for 10 gens)
# Final Gen 47 | best=0.98250793 | stagnant=10/10
# --------------------------------------------------
#
# pop=30, cxpb=0.9, mutpb=0.05
#
# Early stopping at generation 69 (no improvement for 10 gens)
# Final Gen 69 | best=0.98018464 | stagnant=10/10
# --------------------------------------------------
#
# pop=30, cxpb=0.9, mutpb=0.1
#
# Early stopping at generation 56 (no improvement for 10 gens)
# Final Gen 56 | best=0.97863806 | stagnant=10/10
# --------------------------------------------------
#
# pop=50, cxpb=0.5, mutpb=0.05
#
# Early stopping at generation 27 (no improvement for 10 gens)
# Final Gen 27 | best=0.96011495 | stagnant=10/10
# --------------------------------------------------
#
# pop=50, cxpb=0.5, mutpb=0.1
#
# Early stopping at generation 52 (no improvement for 10 gens)
# Final Gen 52 | best=0.97443456 | stagnant=10/10
# --------------------------------------------------
#
# pop=50, cxpb=0.5, mutpb=0.2
#
# Early stopping at generation 38 (no improvement for 10 gens)
# Final Gen 38 | best=0.97912132 | stagnant=10/10
# --------------------------------------------------
#
# pop=50, cxpb=0.7, mutpb=0.05
#
# Early stopping at generation 40 (no improvement for 10 gens)
# Final Gen 40 | best=0.96974490 | stagnant=10/10
# --------------------------------------------------
#
# pop=50, cxpb=0.7, mutpb=0.1
#
# Early stopping at generation 53 (no improvement for 10 gens)
# Final Gen 53 | best=0.97728513 | stagnant=10/10
# --------------------------------------------------
#
# pop=50, cxpb=0.7, mutpb=0.2
#
# Early stopping at generation 44 (no improvement for 10 gens)
# Final Gen 44 | best=0.97125535 | stagnant=10/10
# --------------------------------------------------
#
# pop=50, cxpb=0.9, mutpb=0.05
#
# Early stopping at generation 39 (no improvement for 10 gens)
# Final Gen 39 | best=0.96091562 | stagnant=10/10
# --------------------------------------------------
#
# pop=50, cxpb=0.9, mutpb=0.1
#
# Early stopping at generation 43 (no improvement for 10 gens)
# Final Gen 43 | best=0.97579356 | stagnant=10/10
# --------------------------------------------------
#
# pop=100, cxpb=0.5, mutpb=0.05
#
# Early stopping at generation 33 (no improvement for 10 gens)
# Final Gen 33 | best=0.97110622 | stagnant=10/10
# --------------------------------------------------
#
# pop=100, cxpb=0.5, mutpb=0.1
#
# Early stopping at generation 33 (no improvement for 10 gens)
# Final Gen 33 | best=0.97975344 | stagnant=10/10
# --------------------------------------------------
#
# pop=100, cxpb=0.5, mutpb=0.2
#
# Early stopping at generation 63 (no improvement for 10 gens)
# Final Gen 63 | best=0.98398734 | stagnant=10/10
# --------------------------------------------------
#
# pop=100, cxpb=0.7, mutpb=0.05
#
# Early stopping at generation 33 (no improvement for 10 gens)
# Final Gen 33 | best=0.97286284 | stagnant=10/10
# --------------------------------------------------
#
# pop=100, cxpb=0.7, mutpb=0.1
#
# Early stopping at generation 52 (no improvement for 10 gens)
# Final Gen 52 | best=0.97711557 | stagnant=10/10
# --------------------------------------------------
#
# pop=100, cxpb=0.7, mutpb=0.2
#
# Early stopping at generation 62 (no improvement for 10 gens)
# Final Gen 62 | best=0.97859889 | stagnant=10/10
# --------------------------------------------------
#
# pop=100, cxpb=0.9, mutpb=0.05
#
# Early stopping at generation 31 (no improvement for 10 gens)
# Final Gen 31 | best=0.96971879 | stagnant=10/10
# --------------------------------------------------
#
# pop=100, cxpb=0.9, mutpb=0.1
#
# Early stopping at generation 41 (no improvement for 10 gens)
# Final Gen 41 | best=0.97933629 | stagnant=10/10
# --------------------------------------------------
#
# === Final Summary: Best to Worst Fitness ===
#   Pop |  CxPb | MutPb |    Fitness | Runtime (s)
# --------------------------------------------------
#    30 |  0.50 |  0.20 |   0.984324 |       0.56
#   100 |  0.50 |  0.20 |   0.983987 |       0.62
#    30 |  0.70 |  0.20 |   0.982508 |       0.59
#    30 |  0.70 |  0.10 |   0.982233 |       0.63
#    30 |  0.90 |  0.05 |   0.980185 |       1.00
#   100 |  0.50 |  0.10 |   0.979753 |       0.29
#   100 |  0.90 |  0.10 |   0.979336 |       0.62
#    50 |  0.50 |  0.20 |   0.979121 |       0.37
#    30 |  0.90 |  0.10 |   0.978638 |       0.82
#   100 |  0.70 |  0.20 |   0.978599 |       0.81
#    50 |  0.70 |  0.10 |   0.977285 |       0.62
#   100 |  0.70 |  0.10 |   0.977116 |       0.64
#    30 |  0.50 |  0.10 |   0.975933 |       0.34
#    50 |  0.90 |  0.10 |   0.975794 |       0.64
#    50 |  0.50 |  0.10 |   0.974435 |       0.46
#   100 |  0.70 |  0.05 |   0.972863 |       0.37
#    50 |  0.70 |  0.20 |   0.971255 |       0.56
#   100 |  0.50 |  0.05 |   0.971106 |       0.29
#    30 |  0.70 |  0.05 |   0.970311 |       0.49
#    50 |  0.70 |  0.05 |   0.969745 |       0.45
#   100 |  0.90 |  0.05 |   0.969719 |       0.46
#    30 |  0.50 |  0.05 |   0.962766 |       0.25
#    50 |  0.90 |  0.05 |   0.960916 |       0.57
#    50 |  0.50 |  0.05 |   0.960115 |       0.23

# %%
# Execute the Simulation
# optuna parameter tuning
import optuna

TARGET_KCAL = 1600

results = [] # Store all results

def objective(trial):

    reset_seed()

    pop_size = trial.suggest_int("pop_size", 30, 100)
    cxpb = trial.suggest_float("cxpb", 0.5, 0.9)
    mutpb = trial.suggest_float("mutpb", 0.01, 0.2)

    if cxpb + mutpb > 1.0:
        raise optuna.exceptions.TrialPruned()

    print(f"\npop={pop_size}, cxpb={cxpb:.3f}, mutpb={mutpb:.3f}")
    start_time = time.time()
    best_plan = run_simulation(target_kcal=TARGET_KCAL, pop_size=pop_size, cxpb=cxpb, mutpb=mutpb)
    end_time = time.time()
    runtime_sec = end_time - start_time
    fitness = best_plan.fitness.values[0]

    results.append({ # Add to results
        "pop": pop_size,
        "cxpb": cxpb,
        "mutpb": mutpb,
        "fitness": fitness,
        "runtime_sec": runtime_sec
    })

    return fitness

# Create study
study = optuna.create_study(direction="maximize")

# Run optimization
study.optimize(objective, n_trials=30) # n_trials is number of parameter combinations to try

# Sort results by fitness (best to worst)
results_sorted = sorted(results, key=lambda x: x["fitness"], reverse=True)

# Print summary table
print("\n=== Final Summary: Best to Worst Fitness ===")
print(f"{'Pop':>5} | {'CxPb':>5} | {'MutPb':>5} | {'Fitness':>10} | {'Runtime (s)':>10}")
print("-" * 50)
for r in results_sorted:
    print(f"{r['pop']:>5} | {r['cxpb']:>5.2f} | {r['mutpb']:>5.2f} | {r['fitness']:>10.6f} | {r['runtime_sec']:>10.2f}")
# Out:
# [I 2026-03-31 17:13:02,831] A new study created in memory with name: no-name-30ccc33b-b970-45a5-a3b2-2f54890359c8
# pop=48, cxpb=0.816, mutpb=0.056
# [I 2026-03-31 17:13:03,496] Trial 0 finished with value: 0.9778553252447999 and parameters: {'pop_size': 48, 'cxpb': 0.8159066996854706, 'mutpb': 0.05559565433611913}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 50 (no improvement for 10 gens)
# Final Gen 50 | best=0.97785533 | stagnant=10/10
# --------------------------------------------------
#
# pop=44, cxpb=0.711, mutpb=0.076
# [I 2026-03-31 17:13:03,861] Trial 1 finished with value: 0.9648167611653002 and parameters: {'pop_size': 44, 'cxpb': 0.7111783356303061, 'mutpb': 0.07611737989460002}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 31 (no improvement for 10 gens)
# Final Gen 31 | best=0.96481676 | stagnant=10/10
# --------------------------------------------------
#
# pop=41, cxpb=0.508, mutpb=0.159
# [I 2026-03-31 17:13:04,340] Trial 2 finished with value: 0.9666380519041096 and parameters: {'pop_size': 41, 'cxpb': 0.5081531421129586, 'mutpb': 0.1585117267188842}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 49 (no improvement for 10 gens)
# Final Gen 49 | best=0.96663805 | stagnant=10/10
# --------------------------------------------------
#
# pop=81, cxpb=0.622, mutpb=0.107
# [I 2026-03-31 17:13:04,959] Trial 3 finished with value: 0.9710887494154791 and parameters: {'pop_size': 81, 'cxpb': 0.6216523923756657, 'mutpb': 0.10745799227403093}. Best is trial 0 with value: 0.9778553252447999.
# [I 2026-03-31 17:13:04,960] Trial 4 pruned.
# Early stopping at generation 57 (no improvement for 10 gens)
# Final Gen 57 | best=0.97108875 | stagnant=10/10
# --------------------------------------------------
#
# pop=48, cxpb=0.586, mutpb=0.078
# [I 2026-03-31 17:13:05,507] Trial 5 finished with value: 0.9719677891540582 and parameters: {'pop_size': 48, 'cxpb': 0.5855304596843132, 'mutpb': 0.0779706647021104}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 53 (no improvement for 10 gens)
# Final Gen 53 | best=0.97196779 | stagnant=10/10
# --------------------------------------------------
#
# pop=36, cxpb=0.758, mutpb=0.057
# [I 2026-03-31 17:13:06,207] Trial 6 finished with value: 0.9748919852244393 and parameters: {'pop_size': 36, 'cxpb': 0.7582303200075722, 'mutpb': 0.05704354058757938}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 57 (no improvement for 10 gens)
# Final Gen 57 | best=0.97489199 | stagnant=10/10
# --------------------------------------------------
#
# pop=65, cxpb=0.555, mutpb=0.071
# [I 2026-03-31 17:13:06,647] Trial 7 finished with value: 0.9761869332664754 and parameters: {'pop_size': 65, 'cxpb': 0.5545052383067286, 'mutpb': 0.07085533115148199}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 46 (no improvement for 10 gens)
# Final Gen 46 | best=0.97618693 | stagnant=10/10
# --------------------------------------------------
#
# pop=86, cxpb=0.725, mutpb=0.105
# [I 2026-03-31 17:13:07,184] Trial 8 finished with value: 0.9707604380196051 and parameters: {'pop_size': 86, 'cxpb': 0.7254457900295105, 'mutpb': 0.10468345512250442}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 42 (no improvement for 10 gens)
# Final Gen 42 | best=0.97076044 | stagnant=10/10
# --------------------------------------------------
#
# pop=65, cxpb=0.777, mutpb=0.137
# [I 2026-03-31 17:13:07,747] Trial 9 finished with value: 0.9734551408341465 and parameters: {'pop_size': 65, 'cxpb': 0.7772856766936781, 'mutpb': 0.1366712025285848}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 42 (no improvement for 10 gens)
# Final Gen 42 | best=0.97345514 | stagnant=10/10
# --------------------------------------------------
#
# pop=99, cxpb=0.890, mutpb=0.012
# [I 2026-03-31 17:13:08,081] Trial 10 finished with value: 0.9707273684999642 and parameters: {'pop_size': 99, 'cxpb': 0.8897039604112962, 'mutpb': 0.011794155732323716}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 23 (no improvement for 10 gens)
# Final Gen 23 | best=0.97072737 | stagnant=10/10
# --------------------------------------------------
#
# pop=61, cxpb=0.826, mutpb=0.030
# [I 2026-03-31 17:13:08,451] Trial 11 finished with value: 0.9704048164981529 and parameters: {'pop_size': 61, 'cxpb': 0.8255270853523445, 'mutpb': 0.030105101971174594}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 28 (no improvement for 10 gens)
# Final Gen 28 | best=0.97040482 | stagnant=10/10
# --------------------------------------------------
#
# pop=55, cxpb=0.636, mutpb=0.053
# [I 2026-03-31 17:13:08,797] Trial 12 finished with value: 0.9633971324990656 and parameters: {'pop_size': 55, 'cxpb': 0.635548654932567, 'mutpb': 0.05346929285659504}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 32 (no improvement for 10 gens)
# Final Gen 32 | best=0.96339713 | stagnant=10/10
# --------------------------------------------------
#
# pop=32, cxpb=0.503, mutpb=0.057
# [I 2026-03-31 17:13:09,132] Trial 13 finished with value: 0.9577082756422989 and parameters: {'pop_size': 32, 'cxpb': 0.5034337592617658, 'mutpb': 0.05713889867843627}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 40 (no improvement for 10 gens)
# Final Gen 40 | best=0.95770828 | stagnant=10/10
# --------------------------------------------------
#
# pop=73, cxpb=0.666, mutpb=0.186
# [I 2026-03-31 17:13:09,823] Trial 14 finished with value: 0.9765485078375606 and parameters: {'pop_size': 73, 'cxpb': 0.6657889112272728, 'mutpb': 0.18584797525090269}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 56 (no improvement for 10 gens)
# Final Gen 56 | best=0.97654851 | stagnant=10/10
# --------------------------------------------------
#
# pop=77, cxpb=0.668, mutpb=0.199
# [I 2026-03-31 17:13:10,426] Trial 15 finished with value: 0.9725588402963894 and parameters: {'pop_size': 77, 'cxpb': 0.6682895689239897, 'mutpb': 0.1991403633214629}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 48 (no improvement for 10 gens)
# Final Gen 48 | best=0.97255884 | stagnant=10/10
# --------------------------------------------------
#
# pop=54, cxpb=0.805, mutpb=0.195
# [I 2026-03-31 17:13:11,089] Trial 16 finished with value: 0.9755268210442865 and parameters: {'pop_size': 54, 'cxpb': 0.8049202631098709, 'mutpb': 0.1949497291364508}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 45 (no improvement for 10 gens)
# Final Gen 45 | best=0.97552682 | stagnant=10/10
# --------------------------------------------------
#
# pop=72, cxpb=0.677, mutpb=0.148
# [I 2026-03-31 17:13:11,843] Trial 17 finished with value: 0.977694226160946 and parameters: {'pop_size': 72, 'cxpb': 0.6765921094611361, 'mutpb': 0.14783152882046344}. Best is trial 0 with value: 0.9778553252447999.
# [I 2026-03-31 17:13:11,845] Trial 18 pruned.
# Early stopping at generation 62 (no improvement for 10 gens)
# Final Gen 62 | best=0.97769423 | stagnant=10/10
# --------------------------------------------------
#
# pop=71, cxpb=0.748, mutpb=0.104
# [I 2026-03-31 17:13:12,461] Trial 19 finished with value: 0.9703530607952625 and parameters: {'pop_size': 71, 'cxpb': 0.7479018692089827, 'mutpb': 0.10393329427841436}. Best is trial 0 with value: 0.9778553252447999.
# Early stopping at generation 48 (no improvement for 10 gens)
# Final Gen 48 | best=0.97035306 | stagnant=10/10
# --------------------------------------------------
#
# pop=52, cxpb=0.680, mutpb=0.136
# [I 2026-03-31 17:13:13,259] Trial 20 finished with value: 0.9796234391809029 and parameters: {'pop_size': 52, 'cxpb': 0.6796461321430755, 'mutpb': 0.1358082683308825}. Best is trial 20 with value: 0.9796234391809029.
# Early stopping at generation 66 (no improvement for 10 gens)
# Final Gen 66 | best=0.97962344 | stagnant=10/10
# --------------------------------------------------
#
# pop=53, cxpb=0.670, mutpb=0.145
# [I 2026-03-31 17:13:13,777] Trial 21 finished with value: 0.9750001185965823 and parameters: {'pop_size': 53, 'cxpb': 0.669886448042616, 'mutpb': 0.1452447078081611}. Best is trial 20 with value: 0.9796234391809029.
# Early stopping at generation 43 (no improvement for 10 gens)
# Final Gen 43 | best=0.97500012 | stagnant=10/10
# --------------------------------------------------
#
# pop=59, cxpb=0.704, mutpb=0.121
# [I 2026-03-31 17:13:14,270] Trial 22 finished with value: 0.9795367727697005 and parameters: {'pop_size': 59, 'cxpb': 0.7044049197130963, 'mutpb': 0.12090977375688826}. Best is trial 20 with value: 0.9796234391809029.
# Early stopping at generation 39 (no improvement for 10 gens)
# Final Gen 39 | best=0.97953677 | stagnant=10/10
# --------------------------------------------------
#
# pop=60, cxpb=0.784, mutpb=0.117
# [I 2026-03-31 17:13:14,839] Trial 23 finished with value: 0.9785241201190313 and parameters: {'pop_size': 60, 'cxpb': 0.784007036905016, 'mutpb': 0.11735416535675605}. Best is trial 20 with value: 0.9796234391809029.
# Early stopping at generation 42 (no improvement for 10 gens)
# Final Gen 42 | best=0.97852412 | stagnant=10/10
# --------------------------------------------------
#
# pop=59, cxpb=0.726, mutpb=0.122
# [I 2026-03-31 17:13:15,679] Trial 24 finished with value: 0.9769778058961844 and parameters: {'pop_size': 59, 'cxpb': 0.7264468082727956, 'mutpb': 0.12190476293427785}. Best is trial 20 with value: 0.9796234391809029.
# Early stopping at generation 67 (no improvement for 10 gens)
# Final Gen 67 | best=0.97697781 | stagnant=10/10
# --------------------------------------------------
#
# pop=59, cxpb=0.787, mutpb=0.171
# [I 2026-03-31 17:13:16,302] Trial 25 finished with value: 0.9803997368930385 and parameters: {'pop_size': 59, 'cxpb': 0.7868044975321667, 'mutpb': 0.17116012189435525}. Best is trial 25 with value: 0.9803997368930385.
# Early stopping at generation 44 (no improvement for 10 gens)
# Final Gen 44 | best=0.98039974 | stagnant=10/10
# --------------------------------------------------
#
# pop=50, cxpb=0.627, mutpb=0.174
# [I 2026-03-31 17:13:16,704] Trial 26 finished with value: 0.9716398136745378 and parameters: {'pop_size': 50, 'cxpb': 0.6274036460799326, 'mutpb': 0.174180482901092}. Best is trial 25 with value: 0.9803997368930385.
# Early stopping at generation 35 (no improvement for 10 gens)
# Final Gen 35 | best=0.97163981 | stagnant=10/10
# --------------------------------------------------
#
# pop=38, cxpb=0.697, mutpb=0.172
# [I 2026-03-31 17:13:17,300] Trial 27 finished with value: 0.9773896039062178 and parameters: {'pop_size': 38, 'cxpb': 0.697074752721043, 'mutpb': 0.17209617234923485}. Best is trial 25 with value: 0.9803997368930385.
# Early stopping at generation 48 (no improvement for 10 gens)
# Final Gen 48 | best=0.97738960 | stagnant=10/10
# --------------------------------------------------
#
# pop=68, cxpb=0.759, mutpb=0.091
# [I 2026-03-31 17:13:17,704] Trial 28 finished with value: 0.9751392893857158 and parameters: {'pop_size': 68, 'cxpb': 0.7585333437323107, 'mutpb': 0.09077218515294895}. Best is trial 25 with value: 0.9803997368930385.
# Early stopping at generation 32 (no improvement for 10 gens)
# Final Gen 32 | best=0.97513929 | stagnant=10/10
# --------------------------------------------------
#
# pop=45, cxpb=0.581, mutpb=0.137
# [I 2026-03-31 17:13:18,263] Trial 29 finished with value: 0.9692806914620519 and parameters: {'pop_size': 45, 'cxpb': 0.5813228626688505, 'mutpb': 0.13708845120740681}. Best is trial 25 with value: 0.9803997368930385.
# Early stopping at generation 54 (no improvement for 10 gens)
# Final Gen 54 | best=0.96928069 | stagnant=10/10
# --------------------------------------------------
#
# === Final Summary: Best to Worst Fitness ===
#   Pop |  CxPb | MutPb |    Fitness | Runtime (s)
# --------------------------------------------------
#    59 |  0.79 |  0.17 |   0.980400 |       0.62
#    52 |  0.68 |  0.14 |   0.979623 |       0.80
#    59 |  0.70 |  0.12 |   0.979537 |       0.49
#    60 |  0.78 |  0.12 |   0.978524 |       0.57
#    48 |  0.82 |  0.06 |   0.977855 |       0.66
#    72 |  0.68 |  0.15 |   0.977694 |       0.75
#    38 |  0.70 |  0.17 |   0.977390 |       0.59
#    59 |  0.73 |  0.12 |   0.976978 |       0.84
#    73 |  0.67 |  0.19 |   0.976549 |       0.69
#    65 |  0.55 |  0.07 |   0.976187 |       0.44
#    54 |  0.80 |  0.19 |   0.975527 |       0.66
#    68 |  0.76 |  0.09 |   0.975139 |       0.40
#    53 |  0.67 |  0.15 |   0.975000 |       0.52
#    36 |  0.76 |  0.06 |   0.974892 |       0.70
#    65 |  0.78 |  0.14 |   0.973455 |       0.56
#    77 |  0.67 |  0.20 |   0.972559 |       0.60
#    48 |  0.59 |  0.08 |   0.971968 |       0.55
#    50 |  0.63 |  0.17 |   0.971640 |       0.40
#    81 |  0.62 |  0.11 |   0.971089 |       0.62
#    86 |  0.73 |  0.10 |   0.970760 |       0.54
#    99 |  0.89 |  0.01 |   0.970727 |       0.33
#    61 |  0.83 |  0.03 |   0.970405 |       0.37
#    71 |  0.75 |  0.10 |   0.970353 |       0.61
#    45 |  0.58 |  0.14 |   0.969281 |       0.56
#    41 |  0.51 |  0.16 |   0.966638 |       0.48
#    44 |  0.71 |  0.08 |   0.964817 |       0.36
#    55 |  0.64 |  0.05 |   0.963397 |       0.34
#    32 |  0.50 |  0.06 |   0.957708 |       0.33

# %%
# Random Search Execution
start_time = time.time()

reset_seed()

rs_best, rs_fitness = run_random_search(num_trials=5000)

end_time = time.time()
rs_time = end_time - start_time

print("\nRandom Search Meal:")
print_meal_plan(rs_best)

# Random Search vs Genetic Algorithm
print("\n=== GA vs Random Search ===")
print(f"{'Method':<20} | {'Fitness':<10} | {'Runtime (s)':<10}")
print("-" * 40)

best_ga = results_sorted[0]

print(f"{'Genetic Algorithm':<20} | {best_ga['fitness']:<10.6f} | {best_ga['runtime_sec']:<10.2f}")
print(f"{'Random Search':<20} | {rs_fitness:<10.6f} | {rs_time:<10.2f}")
# Out:
# Random Search Meal:
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1681.4 kcal
# Total Weight:   378.9 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    56.3% | 55.0%
# Protein (p)     |    34.3% | 20.0%
# Fats (f)        |     9.4% | 25.0%
# Meal variety    |   100.0% | 100%
# Meal calorie    |   105.1% | 100%
# User preference |    66.7% | 100%
# ========================================
#
# === GA vs Random Search ===
# Method               | Fitness    | Runtime (s)
# ----------------------------------------
# Genetic Algorithm    | 0.980400   | 0.62
# Random Search        | 0.937526   | 0.38

# %%
# Imports
from dataclasses import dataclass
import random
import numpy as np
from deap import base, creator, tools, algorithms
import csv
from deap.tools import cxOnePoint, cxTwoPoints

random.seed(42)

# %%
# A gene contains 2 attributes : the food item's name and the number of servings of this item
@dataclass
class Gene:
    food_item_name: str
    serving: int

# %%
# We make a list representing all the meals we have in 1 chromosome 
Meals =["Breakfast", "Snack 1", "Lunch", "Snack 2", "Dinner"]
# We make a list representing all the food groups we have in 1 meal
Food_Groups =["Vegetables", "Fruits", "Grains", "Protein", "Dairy", "Fats and Oils"]

# %%
# Load dataset
def load_food_data(csv_path):
    food_data = {}
    meal_flags = {}

    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)

        for row in reader:
            group = row['Category']
            food = row['Food Item']

            if group not in food_data:
                food_data[group] = {}

            # Safely convert numeric columns, use 0 if empty
            def safe_float(x):
                try:
                    return float(x)
                except (ValueError, TypeError):
                    return 0.0

            food_data[group][food] = {
                'p': safe_float(row['Protein (g)']),
                'f': safe_float(row['Fats (g)']),
                'c': safe_float(row['Carbohydrates (g)']),
                'cal': safe_float(row['Calories (kcal)']),
                'pref': safe_float(row['User Preference'])
            }

            # Safely convert meal flags (0 if empty)
            def safe_int(x):
                try:
                    return int(x)
                except (ValueError, TypeError):
                    return 0

            meal_flags[food] = {
                'Breakfast': safe_int(row['Breakfast']),
                'Snack 1': safe_int(row['Snack 1']),
                'Lunch': safe_int(row['Lunch']),
                'Snack 2': safe_int(row['Snack 2']),
                'Dinner': safe_int(row['Dinner'])
            }

    return food_data, meal_flags

FOOD_DATA, MEAL_FLAGS = load_food_data("Processed_Bahrain_Food_Dataset.csv")

# %%
# Dictionary that contains all the saudi guideline's servings
SERVING_GUIDELINES_BY_KCAL = {
    1200: {
        "Breakfast": {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 2, "Fruits": 0, "Fats and Oils": 0},
        "Snack 2":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 0}
    },

    1300: {
        "Breakfast": {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 0}
    },

    1400: {
        "Breakfast": {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 1, "Vegetables": 2, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 0}
    },

    1500: {
        "Breakfast": {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 0, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 2, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 0}
    },

    1600: {
        "Breakfast": {"Grains": 2, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 2, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 0}
    },

    1700: {
        "Breakfast": {"Grains": 3, "Dairy": 1, "Protein": 1, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 2, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 0}
    },

    1800: {
        "Breakfast": {"Grains": 3, "Dairy": 1, "Protein": 2, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 1}
    },

    1900: {
        "Breakfast": {"Grains": 3, "Dairy": 1, "Protein": 2, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 2, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 1, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 1}
    },

    2000: {
        "Breakfast": {"Grains": 3, "Dairy": 1, "Protein": 2, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 2, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 2, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 0}
    },

    2200: {
        "Breakfast": {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 1, "Fruits": 0, "Fats and Oils": 1},
        "Snack 1":    {"Grains": 1, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Lunch":     {"Grains": 3, "Dairy": 1, "Protein": 3, "Vegetables": 2, "Fruits": 0, "Fats and Oils": 1},
        "Snack 2":    {"Grains": 2, "Dairy": 0, "Protein": 0, "Vegetables": 0, "Fruits": 1, "Fats and Oils": 0},
        "Dinner":    {"Grains": 2, "Dairy": 0, "Protein": 2, "Vegetables": 1, "Fruits": 1, "Fats and Oils": 1}
    }
}

# %%
# DEAP Configuration
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()

# Initialize Population
def create_individual():
    # Initializes 30 genes following 1600 kcal
    genes = []
    for meal in Meals:
        for group in Food_Groups:
            # Get the fixed serving count for this meal/group
            serving_count = SERVING_GUIDELINES_BY_KCAL[TARGET_KCAL][meal][group]

           # Filter foods allowed for this meal
            allowed_foods = [
                food for food in FOOD_DATA[group].keys() if MEAL_FLAGS[food][meal] == 1
            ]
            if not allowed_foods:
                allowed_foods = list(FOOD_DATA[group].keys())  # fallback

            # Randomly select food from allowed foods
            food_name = random.choice(allowed_foods)

            # Create gene with guideline serving count
            genes.append(Gene(food_item_name=food_name, serving=serving_count))


    return creator.Individual(genes)

toolbox.register("individual", create_individual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# Fitness Function
def evaluate_meal_plan(individual):
    total_p = 0.0 # Protein grams
    total_f = 0.0 # Fat grams
    total_c = 0.0 # Carbohydrates grams
    total_cal = 0.0 # Total Calories
    total_pref = 0.0 # Total user preference

    # Sum up all grams and calories based on food item and serving count
    for gene in individual:
        group_name = None
        # Find which group this food belongs to
        for group, foods in FOOD_DATA.items():
            if gene.food_item_name in foods:
                group_name = group
                break

        if group_name:
            stats = FOOD_DATA[group_name][gene.food_item_name]
            total_p += stats['p'] * gene.serving
            total_f += stats['f'] * gene.serving
            total_c += stats['c'] * gene.serving
            total_cal += stats['cal'] * gene.serving
            if gene.serving > 0:
              total_pref += stats['pref']
    # Calculate actual macro percentages (p_c, p_p, p_f)
    g_total = total_p + total_f + total_c
    if g_total == 0: return 0, # Avoid division by zero

    p_p = total_p / g_total
    p_f = total_f / g_total
    p_c = total_c / g_total

    # Target Ratios (The AMDR values)
    r_p, r_f, r_c = 0.20, 0.25, 0.55

    # Objective function: J_macro (Squared Error)
    j_macro = (p_c - r_c)**2 + (p_p - r_p)**2 + (p_f - r_f)**2

    # Total calorie constraint (J_cal)
    r = (total_cal - TARGET_KCAL) / TARGET_KCAL
    j_cal = min(1, r**2)

    # Variety constraint (J_var)
    N = sum(1 for gene in individual if gene.serving > 0) # total number of food items in the chromosome (N is taken from the report)
    # count food appearance
    food_appearance={}
    for gene in individual:
        if gene.serving>0:
            food_appearance[gene.food_item_name]= food_appearance.get(gene.food_item_name, 0) + 1
    # Calculate the penalty for variety
    j_var = 0
    for food_name,count in food_appearance.items():
        # we penalize if the food item appears more than once
        if count > 1:
            j_var += max(0,count-1)**2
    # Normalize the penalty
    j_var = j_var / ((N-1)**2)

    # User preference constraint (J_pref)
    j_pref = total_pref / N


    # Calculate the score
    w_macro, w_cal, w_var, w_pref = 0.35, 0.35, 0.15, 0.15 
    score = w_macro * j_macro + w_var * j_var + w_cal * j_cal + w_pref *  j_pref

    # store the penalties to print later
    individual.j_var= j_var
    individual.j_macro = j_macro
    individual.j_cal = j_cal
    individual.j_pref = j_pref

    # We want to minimize score, so we return a fitness that increases as score decreases
    return 1 / (1 + score),

# Crossover
def one_cx_meal_plan(parent1, parent2):
    GROUPS = 6
    MEALS = 5

    m1 = random.randrange(1, MEALS)
    cut = m1 * GROUPS
    parent1[cut:], parent2[cut:] = parent2[cut:], parent1[cut:]
    return parent1, parent2

def two_cx_meal_plan(parent1, parent2):
    GROUPS = 6
    MEALS = 5

    # Choose 2 meal cut points
    m1, m2 = sorted(random.sample(range(1, MEALS), 2))
    cut1, cut2 = m1 * GROUPS, m2 * GROUPS

    # Swap full meals
    parent1[cut1:cut2], parent2[cut1:cut2] = parent2[cut1:cut2], parent1[cut1:cut2]

    return parent1, parent2

# Mutation
def mutate_meal_plan(individual):
    mutations_done = 0
    all_indices = list(range(len(individual))) # List of all possible indices in the chromosome
    random.shuffle(all_indices) # Shuffle to pick randomly without repeating the same one

    for i in all_indices:
        if mutations_done >= 2:
            break  # Stop once we have mutated 2 genes

        # Check if the serving size is not zero
        if individual[i].serving > 0:
            # Find which group it belongs to (Vegetables, Grains, ...)
            group_name = Food_Groups[i % 6]
            # What meal it belongs to (Breakfast, Snack 1,...)
            meal = Meals[i // 6]

            # Check compatibility
            allowed_foods = [
                food for food in FOOD_DATA[group_name].keys() if MEAL_FLAGS[food][meal] == 1
            ]
            if allowed_foods:
                # Pick a new food name from food group dictionary, but the serving remains the same
                individual[i].food_item_name = random.choice(allowed_foods)
                mutations_done += 1
    return individual,

toolbox.register("evaluate", evaluate_meal_plan)
toolbox.register("select", tools.selTournament, tournsize=3) # Tournament selection (From report: For the selection strategy, we plan to compare tournament selection and roulette-wheel selection)
toolbox.register("mate", cxOnePoint) # one-point crossover
toolbox.register("mutate", mutate_meal_plan)
# Out:
# C:\Users\jalaj\OneDrive\Desktop\ML\Project\.venv\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# C:\Users\jalaj\OneDrive\Desktop\ML\Project\.venv\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "

# %%
# Execution Loop
def run_simulation(target_kcal, pop_size, cxpb, mutpb):
    global TARGET_KCAL
    TARGET_KCAL = target_kcal   # tells create_individual which guideline to use

    pop = toolbox.population(n=pop_size) # try 30, 50, 100 (from parameters)

    hof = tools.HallOfFame(1) # Keeps the absolute best found across all generations

    mu = len(pop) # Number of individuals to select for the next generation
    lambd = 100 # Number of children to produce in each generation
    MAX_GEN = 300 #max num no more
    PATIENCE = 10 #after 10 gen if there is no progress stop, try 10, 20, 30 (change at the end after main parameters)
    EPS = 1e-6  #small new update ignor
    best_so_far = None
    stagnant = 0
    # Statistics object
    stats = tools.Statistics(lambda ind: ind.fitness.values[0])
    stats.register("avg", np.mean)
    stats.register("min", np.min)
    stats.register("max", np.max)
    for gen in range(MAX_GEN):

        # run ONE generation
        algorithms.eaMuPlusLambda(
            pop, toolbox,
            mu=mu,
            lambda_=lambd,
            cxpb=cxpb, #try 0.5, 0.7, 0.9 (from parameters)
            mutpb=mutpb, #try 0.05, 0.1, 0.2 (from parameters)
            ngen=1,
            stats=stats,
            halloffame=hof,
            verbose=False
        )
        hof.update(pop)


        current_best = hof[0].fitness.values[0]

        if best_so_far is None or current_best > best_so_far + EPS:
            best_so_far = current_best
            stagnant = 0
        else:
            stagnant += 1

        if stagnant >= PATIENCE:
            print(f"\nEarly stopping at generation {gen+1} (no improvement for {PATIENCE} gens)")
            break
    print(f"Final Gen {gen+1} | best={current_best:.8f} | stagnant={stagnant}/{PATIENCE}")
    print("-" * 50)


    return hof[0]

# %%
def print_meal_plan(individual):
    total_p = total_f = total_c = total_cal = 0.0

    #print(f"\n{'MEAL':<12} | {'GROUP':<14} | {'FOOD ITEM':<25} | {'SERV.':<6} | {'P (g)':<6} | {'F (g)':<6} | {'C (g)':<6} | {'CALS':<6} | {'PREF':<6}")
    #print("-" * 100)

    for i, gene in enumerate(individual):
        meal = Meals[i // 6]
        group = Food_Groups[i % 6]
        stats = FOOD_DATA[group][gene.food_item_name]
        p = stats['p'] * gene.serving
        f = stats['f'] * gene.serving
        c = stats['c'] * gene.serving
        cal = stats['cal'] * gene.serving
        pref = stats['pref'] if gene.serving > 0 else 0
        total_p += p
        total_f += f
        total_c += c
        total_cal += cal
        #print(f"{meal:<12} | {group:<14} | {gene.food_item_name:<25} | {gene.serving:<6} | {p:<6.1f} |{f:<6.1f} | {c:<6.1f} | {cal:<6.1f} | {pref:<6.2f}")

    g_total = total_p + total_f + total_c
    p_p = (total_p / g_total) * 100
    p_f = (total_f / g_total) * 100
    p_c = (total_c / g_total) * 100
    variety = (1 - individual.j_var) * 100
    calories = (total_cal / TARGET_KCAL) * 100
    preference_score = (1 - individual.j_pref) * 100

    print("\n" + "="*40)
    print("       DAILY NUTRITION SUMMARY")
    print("="*40)
    print(f"Total Energy:   {total_cal:.1f} kcal")
    print(f"Total Weight:   {g_total:.1f} g (Macro Grams)")
    print("-" * 40)
    print(f"Nutrient        | Actual % | Target %")
    print(f"Carbs (c)       | {p_c:>7.1f}% | 55.0%")
    print(f"Protein (p)     | {p_p:>7.1f}% | 20.0%")
    print(f"Fats (f)        | {p_f:>7.1f}% | 25.0%")
    print(f"Meal variety    | {variety:>7.1f}% | 100%")
    print(f"Meal calorie    | {calories:>7.1f}% | 100%")
    print(f"User preference | {preference_score:>7.1f}% | 100%")
    print("="*40)

# %%
# Execute the Simulation
# Grid search parameters
pop_sizes = [30, 50, 100]
cx_probs = [0.5, 0.7, 0.9]
mut_probs = [0.05, 0.1, 0.2]

TARGET_KCAL = 1600

results = [] # Results of all parameter combinations

 # Nested loop trying all possible combinations
for pop_size in pop_sizes:
    for cxpb in cx_probs:
        for mutpb in mut_probs:
            if cxpb + mutpb > 1.0:
                continue  # The sum of cxpb and mutpb must be less than or equal to 1, otherwise error
            print(f"\npop={pop_size}, cxpb={cxpb}, mutpb={mutpb}")
            best_plan = run_simulation(TARGET_KCAL, pop_size=pop_size, cxpb=cxpb, mutpb=mutpb)
            print_meal_plan(best_plan)
            results.append({ # Add to results
                "pop": pop_size,
                "cxpb": cxpb,
                "mutpb": mutpb,
                "fitness": best_plan.fitness.values[0]
            })
# Sort results by fitness (best to worst)
results_sorted = sorted(results, key=lambda x: x["fitness"], reverse=True)

# Print summary table
print("\n=== Final Summary: Best to Worst ===")
print(f"{'Pop':>5} | {'CxPb':>5} | {'MutPb':>5} | {'Fitness':>10}")
print("-" * 35)
for r in results_sorted:
    print(f"{r['pop']:>5} | {r['cxpb']:>5.2f} | {r['mutpb']:>5.2f} | {r['fitness']:>10.6f}")
# Out:
# pop=30, cxpb=0.5, mutpb=0.05
#
# Early stopping at generation 30 (no improvement for 10 gens)
# Final Gen 30 | best=0.96276624 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1683.1 kcal
# Total Weight:   339.7 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    54.5% | 55.0%
# Protein (p)     |    25.3% | 20.0%
# Fats (f)        |    20.2% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |   105.2% | 100%
# User preference |    76.4% | 100%
# ========================================
#
# pop=30, cxpb=0.5, mutpb=0.1
#
# Early stopping at generation 32 (no improvement for 10 gens)
# Final Gen 32 | best=0.97879509 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1625.3 kcal
# Total Weight:   317.5 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    55.3% | 55.0%
# Protein (p)     |    21.6% | 20.0%
# Fats (f)        |    23.1% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |   101.6% | 100%
# User preference |    86.1% | 100%
# ========================================
#
# pop=30, cxpb=0.5, mutpb=0.2
#
# Early stopping at generation 65 (no improvement for 10 gens)
# Final Gen 65 | best=0.97269405 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1696.8 kcal
# Total Weight:   340.4 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    57.0% | 55.0%
# Protein (p)     |    22.9% | 20.0%
# Fats (f)        |    20.1% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |   106.0% | 100%
# User preference |    83.3% | 100%
# ========================================
#
# pop=30, cxpb=0.7, mutpb=0.05
#
# Early stopping at generation 28 (no improvement for 10 gens)
# Final Gen 28 | best=0.95916783 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1680.3 kcal
# Total Weight:   349.7 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    60.5% | 55.0%
# Protein (p)     |    22.7% | 20.0%
# Fats (f)        |    16.8% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |   105.0% | 100%
# User preference |    75.0% | 100%
# ========================================
#
# pop=30, cxpb=0.7, mutpb=0.1
#
# Early stopping at generation 51 (no improvement for 10 gens)
# Final Gen 51 | best=0.97333102 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1554.8 kcal
# Total Weight:   322.9 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    58.2% | 55.0%
# Protein (p)     |    24.5% | 20.0%
# Fats (f)        |    17.3% | 25.0%
# Meal variety    |    99.3% | 100%
# Meal calorie    |    97.2% | 100%
# User preference |    84.7% | 100%
# ========================================
#
# pop=30, cxpb=0.7, mutpb=0.2
#
# Early stopping at generation 45 (no improvement for 10 gens)
# Final Gen 45 | best=0.96678561 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1545.3 kcal
# Total Weight:   313.5 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    54.4% | 55.0%
# Protein (p)     |    26.5% | 20.0%
# Fats (f)        |    19.1% | 25.0%
# Meal variety    |   100.0% | 100%
# Meal calorie    |    96.6% | 100%
# User preference |    79.2% | 100%
# ========================================
#
# pop=30, cxpb=0.9, mutpb=0.05
#
# Early stopping at generation 76 (no improvement for 10 gens)
# Final Gen 76 | best=0.97156270 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1607.3 kcal
# Total Weight:   329.0 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    56.7% | 55.0%
# Protein (p)     |    24.5% | 20.0%
# Fats (f)        |    18.7% | 25.0%
# Meal variety    |    98.6% | 100%
# Meal calorie    |   100.5% | 100%
# User preference |    83.3% | 100%
# ========================================
#
# pop=30, cxpb=0.9, mutpb=0.1
#
# Early stopping at generation 31 (no improvement for 10 gens)
# Final Gen 31 | best=0.97938923 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1541.9 kcal
# Total Weight:   302.5 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    52.8% | 55.0%
# Protein (p)     |    25.0% | 20.0%
# Fats (f)        |    22.2% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |    96.4% | 100%
# User preference |    87.5% | 100%
# ========================================
#
# pop=50, cxpb=0.5, mutpb=0.05
#
# Early stopping at generation 49 (no improvement for 10 gens)
# Final Gen 49 | best=0.97202181 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1675.3 kcal
# Total Weight:   341.2 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    54.1% | 55.0%
# Protein (p)     |    27.0% | 20.0%
# Fats (f)        |    19.0% | 25.0%
# Meal variety    |   100.0% | 100%
# Meal calorie    |   104.7% | 100%
# User preference |    83.3% | 100%
# ========================================
#
# pop=50, cxpb=0.5, mutpb=0.1
#
# Early stopping at generation 55 (no improvement for 10 gens)
# Final Gen 55 | best=0.98001560 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1607.8 kcal
# Total Weight:   327.7 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    55.0% | 55.0%
# Protein (p)     |    26.8% | 20.0%
# Fats (f)        |    18.2% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |   100.5% | 100%
# User preference |    88.9% | 100%
# ========================================
#
# pop=50, cxpb=0.5, mutpb=0.2
#
# Early stopping at generation 79 (no improvement for 10 gens)
# Final Gen 79 | best=0.97478188 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1588.6 kcal
# Total Weight:   312.4 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    55.7% | 55.0%
# Protein (p)     |    21.7% | 20.0%
# Fats (f)        |    22.5% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |    99.3% | 100%
# User preference |    83.3% | 100%
# ========================================
#
# pop=50, cxpb=0.7, mutpb=0.05
#
# Early stopping at generation 50 (no improvement for 10 gens)
# Final Gen 50 | best=0.97166249 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1647.8 kcal
# Total Weight:   332.9 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    52.0% | 55.0%
# Protein (p)     |    29.9% | 20.0%
# Fats (f)        |    18.1% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |   103.0% | 100%
# User preference |    84.7% | 100%
# ========================================
#
# pop=50, cxpb=0.7, mutpb=0.1
#
# Early stopping at generation 38 (no improvement for 10 gens)
# Final Gen 38 | best=0.96942314 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1577.5 kcal
# Total Weight:   327.1 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    56.2% | 55.0%
# Protein (p)     |    27.3% | 20.0%
# Fats (f)        |    16.6% | 25.0%
# Meal variety    |    98.6% | 100%
# Meal calorie    |    98.6% | 100%
# User preference |    83.3% | 100%
# ========================================
#
# pop=50, cxpb=0.7, mutpb=0.2
#
# Early stopping at generation 77 (no improvement for 10 gens)
# Final Gen 77 | best=0.98221562 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1606.5 kcal
# Total Weight:   323.3 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    55.6% | 55.0%
# Protein (p)     |    24.2% | 20.0%
# Fats (f)        |    20.2% | 25.0%
# Meal variety    |   100.0% | 100%
# Meal calorie    |   100.4% | 100%
# User preference |    88.9% | 100%
# ========================================
#
# pop=50, cxpb=0.9, mutpb=0.05
#
# Early stopping at generation 40 (no improvement for 10 gens)
# Final Gen 40 | best=0.98013469 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1575.7 kcal
# Total Weight:   323.1 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    56.5% | 55.0%
# Protein (p)     |    25.6% | 20.0%
# Fats (f)        |    17.8% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |    98.5% | 100%
# User preference |    88.9% | 100%
# ========================================
#
# pop=50, cxpb=0.9, mutpb=0.1
#
# Early stopping at generation 35 (no improvement for 10 gens)
# Final Gen 35 | best=0.97212920 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1544.2 kcal
# Total Weight:   320.5 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    58.5% | 55.0%
# Protein (p)     |    24.4% | 20.0%
# Fats (f)        |    17.2% | 25.0%
# Meal variety    |   100.0% | 100%
# Meal calorie    |    96.5% | 100%
# User preference |    83.3% | 100%
# ========================================
#
# pop=100, cxpb=0.5, mutpb=0.05
#
# Early stopping at generation 36 (no improvement for 10 gens)
# Final Gen 36 | best=0.97139127 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1652.1 kcal
# Total Weight:   354.5 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    59.9% | 55.0%
# Protein (p)     |    25.9% | 20.0%
# Fats (f)        |    14.2% | 25.0%
# Meal variety    |   100.0% | 100%
# Meal calorie    |   103.3% | 100%
# User preference |    84.7% | 100%
# ========================================
#
# pop=100, cxpb=0.5, mutpb=0.1
#
# Early stopping at generation 72 (no improvement for 10 gens)
# Final Gen 72 | best=0.97499344 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1536.6 kcal
# Total Weight:   316.6 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    56.5% | 55.0%
# Protein (p)     |    25.3% | 20.0%
# Fats (f)        |    18.2% | 25.0%
# Meal variety    |    99.0% | 100%
# Meal calorie    |    96.0% | 100%
# User preference |    86.1% | 100%
# ========================================
#
# pop=100, cxpb=0.5, mutpb=0.2
#
# Early stopping at generation 55 (no improvement for 10 gens)
# Final Gen 55 | best=0.97738191 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1624.1 kcal
# Total Weight:   330.1 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    54.1% | 55.0%
# Protein (p)     |    27.8% | 20.0%
# Fats (f)        |    18.1% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |   101.5% | 100%
# User preference |    87.5% | 100%
# ========================================
#
# pop=100, cxpb=0.7, mutpb=0.05
#
# Early stopping at generation 42 (no improvement for 10 gens)
# Final Gen 42 | best=0.97679504 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1660.3 kcal
# Total Weight:   334.3 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    54.9% | 55.0%
# Protein (p)     |    25.3% | 20.0%
# Fats (f)        |    19.8% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |   103.8% | 100%
# User preference |    86.1% | 100%
# ========================================
#
# pop=100, cxpb=0.7, mutpb=0.1
#
# Early stopping at generation 52 (no improvement for 10 gens)
# Final Gen 52 | best=0.97906303 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1601.4 kcal
# Total Weight:   312.2 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    54.3% | 55.0%
# Protein (p)     |    23.1% | 20.0%
# Fats (f)        |    22.6% | 25.0%
# Meal variety    |   100.0% | 100%
# Meal calorie    |   100.1% | 100%
# User preference |    86.1% | 100%
# ========================================
#
# pop=100, cxpb=0.7, mutpb=0.2
#
# Early stopping at generation 55 (no improvement for 10 gens)
# Final Gen 55 | best=0.97333988 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1577.4 kcal
# Total Weight:   318.3 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    54.0% | 55.0%
# Protein (p)     |    26.2% | 20.0%
# Fats (f)        |    19.8% | 25.0%
# Meal variety    |   100.0% | 100%
# Meal calorie    |    98.6% | 100%
# User preference |    83.3% | 100%
# ========================================
#
# pop=100, cxpb=0.9, mutpb=0.05
#
# Early stopping at generation 38 (no improvement for 10 gens)
# Final Gen 38 | best=0.96659161 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1615.9 kcal
# Total Weight:   320.0 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    54.0% | 55.0%
# Protein (p)     |    23.5% | 20.0%
# Fats (f)        |    22.5% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |   101.0% | 100%
# User preference |    77.8% | 100%
# ========================================
#
# pop=100, cxpb=0.9, mutpb=0.1
#
# Early stopping at generation 36 (no improvement for 10 gens)
# Final Gen 36 | best=0.97415236 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1649.0 kcal
# Total Weight:   329.2 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    52.3% | 55.0%
# Protein (p)     |    27.8% | 20.0%
# Fats (f)        |    19.9% | 25.0%
# Meal variety    |   100.0% | 100%
# Meal calorie    |   103.1% | 100%
# User preference |    84.7% | 100%
# ========================================
#
# === Final Summary: Best to Worst ===
#   Pop |  CxPb | MutPb |    Fitness
# -----------------------------------
#    50 |  0.70 |  0.20 |   0.982216
#    50 |  0.90 |  0.05 |   0.980135
#    50 |  0.50 |  0.10 |   0.980016
#    30 |  0.90 |  0.10 |   0.979389
#   100 |  0.70 |  0.10 |   0.979063
#    30 |  0.50 |  0.10 |   0.978795
#   100 |  0.50 |  0.20 |   0.977382
#   100 |  0.70 |  0.05 |   0.976795
#   100 |  0.50 |  0.10 |   0.974993
#    50 |  0.50 |  0.20 |   0.974782
#   100 |  0.90 |  0.10 |   0.974152
#   100 |  0.70 |  0.20 |   0.973340
#    30 |  0.70 |  0.10 |   0.973331
#    30 |  0.50 |  0.20 |   0.972694
#    50 |  0.90 |  0.10 |   0.972129
#    50 |  0.50 |  0.05 |   0.972022
#    50 |  0.70 |  0.05 |   0.971662
#    30 |  0.90 |  0.05 |   0.971563
#   100 |  0.50 |  0.05 |   0.971391
#    50 |  0.70 |  0.10 |   0.969423
#    30 |  0.70 |  0.20 |   0.966786
#   100 |  0.90 |  0.05 |   0.966592
#    30 |  0.50 |  0.05 |   0.962766
#    30 |  0.70 |  0.05 |   0.959168

# %%
# Execute the Simulation
# optuna parameter tuning
import optuna

TARGET_KCAL = 1600

results = [] # Store all results

def objective(trial):
    pop_size = trial.suggest_int("pop_size", 30, 100)
    cxpb = trial.suggest_float("cxpb", 0.5, 0.9)
    mutpb = trial.suggest_float("mutpb", 0.01, 0.2)

    if cxpb + mutpb > 1.0:
        raise optuna.exceptions.TrialPruned()

    print(f"\npop={pop_size}, cxpb={cxpb:.3f}, mutpb={mutpb:.3f}")

    best_plan = run_simulation(target_kcal=TARGET_KCAL, pop_size=pop_size, cxpb=cxpb, mutpb=mutpb)

    fitness = best_plan.fitness.values[0]

    results.append({ # Add to results
        "pop": pop_size,
        "cxpb": cxpb,
        "mutpb": mutpb,
        "fitness": fitness
    })

    return fitness

# Create study
study = optuna.create_study(direction="maximize")

# Run optimization
study.optimize(objective, n_trials=30) # n_trials is number of parameter combinations to try

# Sort results by fitness (best to worst)
results_sorted = sorted(results, key=lambda x: x["fitness"], reverse=True)

# Print summary table
print("\n=== Final Summary: Best to Worst (Optuna) ===")
print(f"{'Pop':>5} | {'CxPb':>5} | {'MutPb':>5} | {'Fitness':>10}")
print("-" * 35)
for r in results_sorted:
    print(f"{r['pop']:>5} | {r['cxpb']:>5.2f} | {r['mutpb']:>5.2f} | {r['fitness']:>10.6f}")

best_params = results_sorted[0]

# Run again with best parameters
best_plan = run_simulation(
    TARGET_KCAL,
    pop_size=best_params["pop"],
    cxpb=best_params["cxpb"],
    mutpb=best_params["mutpb"]
)
print_meal_plan(best_plan)
# Out:
# [I 2026-02-23 20:52:32,019] A new study created in memory with name: no-name-7a078d44-d13e-4efa-a22f-45c0b42866a2
# pop=93, cxpb=0.822, mutpb=0.019
# [I 2026-02-23 20:52:33,607] Trial 0 finished with value: 0.9652444207763468 and parameters: {'pop_size': 93, 'cxpb': 0.8219584847785398, 'mutpb': 0.019287004592076502}. Best is trial 0 with value: 0.9652444207763468.
# Early stopping at generation 40 (no improvement for 10 gens)
# Final Gen 40 | best=0.96524442 | stagnant=10/10
# --------------------------------------------------
#
# pop=30, cxpb=0.772, mutpb=0.195
# [I 2026-02-23 20:52:35,455] Trial 1 finished with value: 0.9799612945244276 and parameters: {'pop_size': 30, 'cxpb': 0.7719882613089745, 'mutpb': 0.1951517393361124}. Best is trial 1 with value: 0.9799612945244276.
# Early stopping at generation 54 (no improvement for 10 gens)
# Final Gen 54 | best=0.97996129 | stagnant=10/10
# --------------------------------------------------
#
# pop=81, cxpb=0.769, mutpb=0.074
# [I 2026-02-23 20:52:36,606] Trial 2 finished with value: 0.9626066640024431 and parameters: {'pop_size': 81, 'cxpb': 0.7688678926047721, 'mutpb': 0.07358763547530778}. Best is trial 1 with value: 0.9799612945244276.
# Early stopping at generation 38 (no improvement for 10 gens)
# Final Gen 38 | best=0.96260666 | stagnant=10/10
# --------------------------------------------------
#
# pop=64, cxpb=0.563, mutpb=0.176
# [I 2026-02-23 20:52:37,467] Trial 3 finished with value: 0.9722554604609843 and parameters: {'pop_size': 64, 'cxpb': 0.5625812141839368, 'mutpb': 0.17601012362772592}. Best is trial 1 with value: 0.9799612945244276.
# [I 2026-02-23 20:52:37,468] Trial 4 pruned.
# Early stopping at generation 35 (no improvement for 10 gens)
# Final Gen 35 | best=0.97225546 | stagnant=10/10
# --------------------------------------------------
#
# pop=91, cxpb=0.648, mutpb=0.025
# [I 2026-02-23 20:52:38,637] Trial 5 finished with value: 0.9699492729379803 and parameters: {'pop_size': 91, 'cxpb': 0.6481921243407255, 'mutpb': 0.024614807932741952}. Best is trial 1 with value: 0.9799612945244276.
# Early stopping at generation 43 (no improvement for 10 gens)
# Final Gen 43 | best=0.96994927 | stagnant=10/10
# --------------------------------------------------
#
# pop=94, cxpb=0.632, mutpb=0.197
# [I 2026-02-23 20:52:40,497] Trial 6 finished with value: 0.9774491660666814 and parameters: {'pop_size': 94, 'cxpb': 0.6318506312310621, 'mutpb': 0.1967780870243995}. Best is trial 1 with value: 0.9799612945244276.
# Early stopping at generation 65 (no improvement for 10 gens)
# Final Gen 65 | best=0.97744917 | stagnant=10/10
# --------------------------------------------------
#
# pop=98, cxpb=0.543, mutpb=0.177
# [I 2026-02-23 20:52:41,615] Trial 7 finished with value: 0.9773409597698336 and parameters: {'pop_size': 98, 'cxpb': 0.5429593325760187, 'mutpb': 0.17700088669375225}. Best is trial 1 with value: 0.9799612945244276.
# Early stopping at generation 42 (no improvement for 10 gens)
# Final Gen 42 | best=0.97734096 | stagnant=10/10
# --------------------------------------------------
#
# pop=47, cxpb=0.516, mutpb=0.114
# [I 2026-02-23 20:52:42,650] Trial 8 finished with value: 0.9752778935204297 and parameters: {'pop_size': 47, 'cxpb': 0.5158692028328113, 'mutpb': 0.11387441842644117}. Best is trial 1 with value: 0.9799612945244276.
# Early stopping at generation 48 (no improvement for 10 gens)
# Final Gen 48 | best=0.97527789 | stagnant=10/10
# --------------------------------------------------
#
# pop=47, cxpb=0.808, mutpb=0.191
# [I 2026-02-23 20:52:44,795] Trial 9 finished with value: 0.9760102072371869 and parameters: {'pop_size': 47, 'cxpb': 0.8078650778212062, 'mutpb': 0.19088589984913812}. Best is trial 1 with value: 0.9799612945244276.
# Early stopping at generation 60 (no improvement for 10 gens)
# Final Gen 60 | best=0.97601021 | stagnant=10/10
# --------------------------------------------------
#
# pop=32, cxpb=0.732, mutpb=0.131
# [I 2026-02-23 20:52:46,199] Trial 10 finished with value: 0.9782902302144159 and parameters: {'pop_size': 32, 'cxpb': 0.7321263669083211, 'mutpb': 0.13138167294278097}. Best is trial 1 with value: 0.9799612945244276.
# Early stopping at generation 47 (no improvement for 10 gens)
# Final Gen 47 | best=0.97829023 | stagnant=10/10
# --------------------------------------------------
#
# pop=30, cxpb=0.716, mutpb=0.132
# [I 2026-02-23 20:52:47,901] Trial 11 finished with value: 0.9700334363508255 and parameters: {'pop_size': 30, 'cxpb': 0.7157361783975146, 'mutpb': 0.13167780899580844}. Best is trial 1 with value: 0.9799612945244276.
# Early stopping at generation 58 (no improvement for 10 gens)
# Final Gen 58 | best=0.97003344 | stagnant=10/10
# --------------------------------------------------
#
# pop=30, cxpb=0.716, mutpb=0.080
# [I 2026-02-23 20:52:48,818] Trial 12 finished with value: 0.9667099376483114 and parameters: {'pop_size': 30, 'cxpb': 0.715982516143848, 'mutpb': 0.07960095923349778}. Best is trial 1 with value: 0.9799612945244276.
# Early stopping at generation 32 (no improvement for 10 gens)
# Final Gen 32 | best=0.96670994 | stagnant=10/10
# --------------------------------------------------
#
# pop=42, cxpb=0.760, mutpb=0.155
# [I 2026-02-23 20:52:50,686] Trial 13 finished with value: 0.9786177760525838 and parameters: {'pop_size': 42, 'cxpb': 0.7600565594721346, 'mutpb': 0.1553980763037024}. Best is trial 1 with value: 0.9799612945244276.
# [I 2026-02-23 20:52:50,695] Trial 14 pruned.
# Early stopping at generation 56 (no improvement for 10 gens)
# Final Gen 56 | best=0.97861778 | stagnant=10/10
# --------------------------------------------------
#
# pop=61, cxpb=0.790, mutpb=0.159
# [I 2026-02-23 20:52:51,833] Trial 15 finished with value: 0.979539819672683 and parameters: {'pop_size': 61, 'cxpb': 0.7898246358305446, 'mutpb': 0.15899322732566362}. Best is trial 1 with value: 0.9799612945244276.
# Early stopping at generation 34 (no improvement for 10 gens)
# Final Gen 34 | best=0.97953982 | stagnant=10/10
# --------------------------------------------------
#
# pop=64, cxpb=0.818, mutpb=0.175
# [I 2026-02-23 20:52:53,350] Trial 16 finished with value: 0.9814053330519845 and parameters: {'pop_size': 64, 'cxpb': 0.8175708336341145, 'mutpb': 0.17499150857248583}. Best is trial 16 with value: 0.9814053330519845.
# Early stopping at generation 40 (no improvement for 10 gens)
# Final Gen 40 | best=0.98140533 | stagnant=10/10
# --------------------------------------------------
#
# pop=76, cxpb=0.838, mutpb=0.084
# [I 2026-02-23 20:52:54,266] Trial 17 finished with value: 0.9746639895544547 and parameters: {'pop_size': 76, 'cxpb': 0.8376480201827753, 'mutpb': 0.08424826421287893}. Best is trial 16 with value: 0.9814053330519845.
# Early stopping at generation 27 (no improvement for 10 gens)
# Final Gen 27 | best=0.97466399 | stagnant=10/10
# --------------------------------------------------
#
# pop=58, cxpb=0.664, mutpb=0.051
# [I 2026-02-23 20:52:55,097] Trial 18 finished with value: 0.9698017255029887 and parameters: {'pop_size': 58, 'cxpb': 0.6642318096878089, 'mutpb': 0.05078242529880919}. Best is trial 16 with value: 0.9814053330519845.
# [I 2026-02-23 20:52:55,104] Trial 19 pruned.
# [I 2026-02-23 20:52:55,110] Trial 20 pruned.
# Early stopping at generation 27 (no improvement for 10 gens)
# Final Gen 27 | best=0.96980173 | stagnant=10/10
# --------------------------------------------------
#
# pop=70, cxpb=0.779, mutpb=0.139
# [I 2026-02-23 20:52:56,660] Trial 21 finished with value: 0.9743461981235937 and parameters: {'pop_size': 70, 'cxpb': 0.7788449826272541, 'mutpb': 0.1388098016358834}. Best is trial 16 with value: 0.9814053330519845.
# Early stopping at generation 46 (no improvement for 10 gens)
# Final Gen 46 | best=0.97434620 | stagnant=10/10
# --------------------------------------------------
#
# pop=57, cxpb=0.798, mutpb=0.164
# [I 2026-02-23 20:52:57,909] Trial 22 finished with value: 0.9725785599717809 and parameters: {'pop_size': 57, 'cxpb': 0.7976802557738352, 'mutpb': 0.1639202392705454}. Best is trial 16 with value: 0.9814053330519845.
# Early stopping at generation 34 (no improvement for 10 gens)
# Final Gen 34 | best=0.97257856 | stagnant=10/10
# --------------------------------------------------
#
# pop=65, cxpb=0.742, mutpb=0.182
# [I 2026-02-23 20:52:59,150] Trial 23 finished with value: 0.9776978121677562 and parameters: {'pop_size': 65, 'cxpb': 0.7418698474516247, 'mutpb': 0.18225887732710908}. Best is trial 16 with value: 0.9814053330519845.
# Early stopping at generation 38 (no improvement for 10 gens)
# Final Gen 38 | best=0.97769781 | stagnant=10/10
# --------------------------------------------------
#
# pop=38, cxpb=0.682, mutpb=0.111
# [I 2026-02-23 20:53:00,413] Trial 24 finished with value: 0.9704957288277387 and parameters: {'pop_size': 38, 'cxpb': 0.6816173447673817, 'mutpb': 0.11148924370919298}. Best is trial 16 with value: 0.9814053330519845.
# Early stopping at generation 42 (no improvement for 10 gens)
# Final Gen 42 | best=0.97049573 | stagnant=10/10
# --------------------------------------------------
#
# pop=53, cxpb=0.848, mutpb=0.141
# [I 2026-02-23 20:53:02,033] Trial 25 finished with value: 0.9777404525636145 and parameters: {'pop_size': 53, 'cxpb': 0.8481587059286548, 'mutpb': 0.14077297359644614}. Best is trial 16 with value: 0.9814053330519845.
# Early stopping at generation 43 (no improvement for 10 gens)
# Final Gen 43 | best=0.97774045 | stagnant=10/10
# --------------------------------------------------
#
# pop=86, cxpb=0.791, mutpb=0.169
# [I 2026-02-23 20:53:03,189] Trial 26 finished with value: 0.9775140643135303 and parameters: {'pop_size': 86, 'cxpb': 0.7908629906119897, 'mutpb': 0.16885335521249037}. Best is trial 16 with value: 0.9814053330519845.
# Early stopping at generation 33 (no improvement for 10 gens)
# Final Gen 33 | best=0.97751406 | stagnant=10/10
# --------------------------------------------------
#
# pop=70, cxpb=0.603, mutpb=0.183
# [I 2026-02-23 20:53:04,493] Trial 27 finished with value: 0.9714623824203655 and parameters: {'pop_size': 70, 'cxpb': 0.6029371010981759, 'mutpb': 0.18334771970372093}. Best is trial 16 with value: 0.9814053330519845.
# Early stopping at generation 47 (no improvement for 10 gens)
# Final Gen 47 | best=0.97146238 | stagnant=10/10
# --------------------------------------------------
#
# pop=61, cxpb=0.751, mutpb=0.200
# [I 2026-02-23 20:53:06,175] Trial 28 finished with value: 0.9770152772892958 and parameters: {'pop_size': 61, 'cxpb': 0.7505616455852798, 'mutpb': 0.19976580305665664}. Best is trial 16 with value: 0.9814053330519845.
# Early stopping at generation 48 (no improvement for 10 gens)
# Final Gen 48 | best=0.97701528 | stagnant=10/10
# --------------------------------------------------
#
# pop=51, cxpb=0.825, mutpb=0.098
# [I 2026-02-23 20:53:08,377] Trial 29 finished with value: 0.9761728391099427 and parameters: {'pop_size': 51, 'cxpb': 0.8250129942079598, 'mutpb': 0.09796797138898561}. Best is trial 16 with value: 0.9814053330519845.
# Early stopping at generation 65 (no improvement for 10 gens)
# Final Gen 65 | best=0.97617284 | stagnant=10/10
# --------------------------------------------------
#
# === Final Summary: Best to Worst (Optuna) ===
#   Pop |  CxPb | MutPb |    Fitness
# -----------------------------------
#    64 |  0.82 |  0.17 |   0.981405
#    30 |  0.77 |  0.20 |   0.979961
#    61 |  0.79 |  0.16 |   0.979540
#    42 |  0.76 |  0.16 |   0.978618
#    32 |  0.73 |  0.13 |   0.978290
#    53 |  0.85 |  0.14 |   0.977740
#    65 |  0.74 |  0.18 |   0.977698
#    86 |  0.79 |  0.17 |   0.977514
#    94 |  0.63 |  0.20 |   0.977449
#    98 |  0.54 |  0.18 |   0.977341
#    61 |  0.75 |  0.20 |   0.977015
#    51 |  0.83 |  0.10 |   0.976173
#    47 |  0.81 |  0.19 |   0.976010
#    47 |  0.52 |  0.11 |   0.975278
#    76 |  0.84 |  0.08 |   0.974664
#    70 |  0.78 |  0.14 |   0.974346
#    57 |  0.80 |  0.16 |   0.972579
#    64 |  0.56 |  0.18 |   0.972255
#    70 |  0.60 |  0.18 |   0.971462
#    38 |  0.68 |  0.11 |   0.970496
#    30 |  0.72 |  0.13 |   0.970033
#    91 |  0.65 |  0.02 |   0.969949
#    58 |  0.66 |  0.05 |   0.969802
#    30 |  0.72 |  0.08 |   0.966710
#    93 |  0.82 |  0.02 |   0.965244
#    81 |  0.77 |  0.07 |   0.962607
#
# Early stopping at generation 56 (no improvement for 10 gens)
# Final Gen 56 | best=0.97870536 | stagnant=10/10
# --------------------------------------------------
#
# ========================================
#        DAILY NUTRITION SUMMARY
# ========================================
# Total Energy:   1545.0 kcal
# Total Weight:   325.6 g (Macro Grams)
# ----------------------------------------
# Nutrient        | Actual % | Target %
# Carbs (c)       |    57.7% | 55.0%
# Protein (p)     |    26.0% | 20.0%
# Fats (f)        |    16.3% | 25.0%
# Meal variety    |    99.7% | 100%
# Meal calorie    |    96.6% | 100%
# User preference |    88.9% | 100%
# ========================================
